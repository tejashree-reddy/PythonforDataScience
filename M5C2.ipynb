# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##### 1.Compute how much total salary cost has increased from year 2011 to 2014

# %%
sal=pd.read_csv("Salaries.csv")
sal
# Out:
# c:\users\welcome\appdata\local\programs\python\python37-32\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148643  148646   Carolyn A Wilson
# 148644  148648     Joann Anderson
# 148645  148649        Leon Walker
# 148646  148650      Roy I Tillery
# 148647  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# ...

# %%
sal.columns
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148648 entries, 0 to 148647
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148648 non-null  int64
#  1   EmployeeName      148648 non-null  object
#  2   JobTitle          148648 non-null  object
#  3   BasePay           148043 non-null  float64
#  4   OvertimePay       148648 non-null  float64
#  5   OtherPay          148648 non-null  float64
#  6   Benefits          112490 non-null  float64
#  7   TotalPay          148648 non-null  float64
#  8   TotalPayBenefits  148648 non-null  float64
#  9   Year              148648 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148648 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(7), int64(2), object(4)
# memory usage: 12.5+ MB

# %%
saldata=sal.loc[:,['Year','TotalPay']]
saldata
# Out:
#         Year   TotalPay
# 0       2011  567595.43
# 1       2011  538909.28
# 2       2011  335279.91
# 3       2011  332343.61
# 4       2011  326373.19
# ...      ...        ...
# 148643  2014       0.00
# 148644  2014       0.00
# 148645  2014       0.00
# 148646  2014       0.00
# 148647  2014    -618.13
#
# [148648 rows x 2 columns]

# %%
increase_sal=saldata.groupby("Year").mean().reset_index()
increase_sal
# Out:
#    Year      TotalPay
# 0  2011  71743.819645
# 1  2012  74112.234931
# 2  2013  77611.443142
# 3  2014  75471.836912

# %%
plt.bar(increase_sal["Year"],increase_sal["TotalPay"])
plt.xlabel("Year")
plt.ylabel("Salaries")
plt.show()

# %% [markdown]
# ##### 2.Which Job Title in Year 2014 has highest mean salary?

# %%
Job=sal.loc[sal["Year"]==2014]
Job
# Out:
#             Id          EmployeeName                     JobTitle    BasePay  \
# 110529  110532           David Shinn               Deputy Chief 3  129150.01
# 110530  110533            Amy P Hart            Asst Med Examiner  318835.49
# 110531  110534  William J Coaker Jr.     Chief Investment Officer  257340.00
# 110532  110535        Gregory P Suhr              Chief of Police  307450.04
# 110533  110536  Joanne M Hayes-White       Chief, Fire Department  302068.00
# ...        ...                   ...                          ...        ...
# 148643  148646      Carolyn A Wilson    Human Services Technician       0.00
# 148644  148648        Joann Anderson  Communications Dispatcher 2       0.00
# 148645  148649           Leon Walker                    Custodian       0.00
# 148646  148650         Roy I Tillery                    Custodian       0.00
# 148647  148654             Joe Lopez   Counselor, Log Cabin Ranch       0.00
#
# ...

# %%
J=Job.loc[:,["JobTitle","TotalPay","Year"]]
J
# Out:
#                            JobTitle   TotalPay  Year
# 110529               Deputy Chief 3  471952.64  2014
# 110530            Asst Med Examiner  390111.98  2014
# 110531     Chief Investment Officer  339653.70  2014
# 110532              Chief of Police  326716.76  2014
# 110533       Chief, Fire Department  326233.44  2014
# ...                             ...        ...   ...
# 148643    Human Services Technician       0.00  2014
# 148644  Communications Dispatcher 2       0.00  2014
# 148645                    Custodian       0.00  2014
# 148646                    Custodian       0.00  2014
# 148647   Counselor, Log Cabin Ranch    -618.13  2014
#
# [38119 rows x 3 columns]

# %%
jobSal=J.groupby("JobTitle").mean().reset_index()
jobSal
# Out:
#                            JobTitle       TotalPay  Year
# 0       ACPO,JuvP, Juv Prob (SFERS)   62290.780000  2014
# 1      ASR Senior Office Specialist   62386.654091  2014
# 2              ASR-Office Assistant   44687.796000  2014
# 3                     Account Clerk   37681.233226  2014
# 4                      Accountant I   45404.635000  2014
# ..                              ...            ...   ...
# 991      Wire Rope Cable Maint Sprv  190575.900000  2014
# 992      Worker's Comp Supervisor 1   56689.446667  2014
# 993  Worker's Compensation Adjuster   70636.455385  2014
# 994           X-Ray Laboratory Aide   51211.566857  2014
# 995              Youth Comm Advisor   36465.910000  2014
#
# [996 rows x 3 columns]

# %%
jobSal[jobSal["TotalPay"]==jobSal["TotalPay"].max()]
# Out:
#                      JobTitle  TotalPay  Year
# 178  Chief Investment Officer  339653.7  2014

# %% [markdown]
# ##### 3.How much money could have been saved in Year 2014 by stopping OverTimePay?

# %%
OT=Job.loc[:,["JobTitle","OvertimePay","TotalPay","Year"]]
OT
# Out:
#                            JobTitle  OvertimePay   TotalPay  Year
# 110529               Deputy Chief 3         0.00  471952.64  2014
# 110530            Asst Med Examiner     10712.95  390111.98  2014
# 110531     Chief Investment Officer         0.00  339653.70  2014
# 110532              Chief of Police         0.00  326716.76  2014
# 110533       Chief, Fire Department         0.00  326233.44  2014
# ...                             ...          ...        ...   ...
# 148643    Human Services Technician         0.00       0.00  2014
# 148644  Communications Dispatcher 2         0.00       0.00  2014
# 148645                    Custodian         0.00       0.00  2014
# 148646                    Custodian         0.00       0.00  2014
# 148647   Counselor, Log Cabin Ranch         0.00    -618.13  2014
#
# [38119 rows x 4 columns]

# %%
OT["TotalPay"].sum()-OT["OvertimePay"].sum()
# Out:
# 2670992351.99

# %% [markdown]
# ##### 4.Which are the top 5 common job in Year 2014 and how much do they cost SFO ?

# %%
J["JobTitle"].value_counts()
# Out:
# Transit Operator                2479
# Special Nurse                   1478
# Registered Nurse                1234
# Public Svc Aide-Public Works     916
# Firefighter                      815
#                                 ...
# Roofer Supervisor 1                1
# Media Production Specialist        1
# Senior Plan Checker                1
# Dir Emp Relations Div              1
# Signal and Systems Engineer        1
# Name: JobTitle, Length: 996, dtype: int64

# %%
topJobs=J.loc[J["JobTitle"].isin(["Transit Operator","Special Nurse","Registered Nurse","Public Svc Aide-Public Works","Firefighter"])]
topJobs
# Out:
#                 JobTitle   TotalPay  Year
# 110580       Firefighter  276495.41  2014
# 110591       Firefighter  270408.27  2014
# 110606       Firefighter  260943.62  2014
# 110623       Firefighter  253736.41  2014
# 110688       Firefighter  234568.41  2014
# ...                  ...        ...   ...
# 148608     Special Nurse      21.22  2014
# 148611     Special Nurse      19.97  2014
# 148613  Registered Nurse      19.27  2014
# 148619  Transit Operator      15.35  2014
# 148623  Registered Nurse       6.00  2014
#
# [6922 rows x 3 columns]

# %%
topJobs.groupby(["JobTitle"])["TotalPay"].sum().to_frame().reset_index()
# Out:
#                        JobTitle      TotalPay
# 0                   Firefighter  1.132836e+08
# 1  Public Svc Aide-Public Works  8.535454e+06
# 2              Registered Nurse  1.444065e+08
# 3                 Special Nurse  4.949874e+07
# 4              Transit Operator  1.520080e+08

# %% [markdown]
# ##### 5.Who was the top earning employee across all the years?

# %%
topPay=sal.loc[:,['EmployeeName','Year','TotalPay']]
topPay
# Out:
#              EmployeeName  Year   TotalPay
# 0          NATHANIEL FORD  2011  567595.43
# 1            GARY JIMENEZ  2011  538909.28
# 2          ALBERT PARDINI  2011  335279.91
# 3       CHRISTOPHER CHONG  2011  332343.61
# 4         PATRICK GARDNER  2011  326373.19
# ...                   ...   ...        ...
# 148643   Carolyn A Wilson  2014       0.00
# 148644     Joann Anderson  2014       0.00
# 148645        Leon Walker  2014       0.00
# 148646      Roy I Tillery  2014       0.00
# 148647          Joe Lopez  2014    -618.13
#
# [148648 rows x 3 columns]

# %%
topEmp=topPay.groupby("Year")["TotalPay"].max().to_frame().reset_index()
topEmp
# Out:
#    Year   TotalPay
# 0  2011  567595.43
# 1  2012  362844.66
# 2  2013  347102.32
# 3  2014  471952.64

# %%
result = pd.merge(topPay,topEmp,on='TotalPay')
result
# Out:
#      EmployeeName  Year_x   TotalPay  Year_y
# 0  NATHANIEL FORD    2011  567595.43    2011
# 1  Gary Altenberg    2012  362844.66    2012
# 2     Samson  Lai    2013  347102.32    2013
# 3     David Shinn    2014  471952.64    2014

# %% [markdown]
# ##### 1.Which are the last 5 common job in Year 2014 and how much do they cost SFO?

# %%
J["JobTitle"].value_counts().tail()
# Out:
# Roofer Supervisor 1            1
# Media Production Specialist    1
# Senior Plan Checker            1
# Dir Emp Relations Div          1
# Signal and Systems Engineer    1
# Name: JobTitle, dtype: int64

# %%
lastJobs=J.loc[J["JobTitle"].isin(["Roofer Supervisor 1","Media Production Specialist","Senior Plan Checker","Dir Emp Relations Div","Signal and Systems Engineer"])]
lastJobs
# Out:
#                            JobTitle   TotalPay  Year
# 110752        Dir Emp Relations Div  206872.05  2014
# 118127          Senior Plan Checker  116567.02  2014
# 123666          Roofer Supervisor 1   90489.48  2014
# 129586  Media Production Specialist   71636.84  2014
# 139524  Signal and Systems Engineer   39644.55  2014

# %%
lastJobs.groupby(["JobTitle"])["TotalPay"].sum().to_frame().reset_index()
# Out:
#                       JobTitle   TotalPay
# 0        Dir Emp Relations Div  206872.05
# 1  Media Production Specialist   71636.84
# 2          Roofer Supervisor 1   90489.48
# 3          Senior Plan Checker  116567.02
# 4  Signal and Systems Engineer   39644.55

# %% [markdown]
# ##### 2.In year 2011 OverTimePay was what percentage of  TotalPayBenefits

# %%
data2011=sal.loc[sal["Year"]==2011]
data2011
# Out:
#           Id        EmployeeName  \
# 0          1      NATHANIEL FORD
# 1          2        GARY JIMENEZ
# 2          3      ALBERT PARDINI
# 3          4   CHRISTOPHER CHONG
# 4          5     PATRICK GARDNER
# ...      ...                 ...
# 36153  36155       SERENA HUGHES
# 36154  36156        JOE BROWN JR
# 36155  36157      PAULETTE ADAMS
# 36156  36158       KAUKAB MOHSIN
# 36157  36159  JOSEPHINE MCCREARY
#
#                                              JobTitle    BasePay  OvertimePay  \
# 0      GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.00
# 1                     CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
# 2                     CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
# 3                WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.71
# 4        DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
# ...                                               ...        ...          ...
# ...

# %%
cal=data2011.loc[:,['OvertimePay','TotalPayBenefits']]
cal
# Out:
#        OvertimePay  TotalPayBenefits
# 0             0.00         567595.43
# 1        245131.88         538909.28
# 2        106088.18         335279.91
# 3         56120.71         332343.61
# 4          9737.00         326373.19
# ...            ...               ...
# 36153         0.00              4.17
# 36154         0.00              0.30
# 36155         0.00              0.00
# 36156         0.00              0.00
# 36157         0.00              0.00
#
# [36158 rows x 2 columns]

# %%
cal["OvertimePay"].sum()-cal["TotalPayBenefits"].sum()
# Out:
# -2430293919.7999997

# %%
(cal["TotalPayBenefits"].sum()-cal["OvertimePay"].sum())/cal["TotalPayBenefits"].sum()
# Out:
# 0.9368496634572119

# %%
((cal["TotalPayBenefits"].sum()-cal["OvertimePay"].sum())/cal["TotalPayBenefits"].sum())*100
# Out:
# 93.6849663457212

# %%
cal["percentage"]=(cal["TotalPayBenefits"]-cal["OvertimePay"])/cal["TotalPayBenefits"]
cal["percentage"]*100
# Out:
# 0        100.000000
# 1         54.513331
# 2         68.358325
# 3         83.113649
# 4         97.016605
#             ...
# 36153    100.000000
# 36154    100.000000
# 36155           NaN
# 36156           NaN
# 36157           NaN
# Name: percentage, Length: 36158, dtype: float64

# %% [markdown]
# ##### 3.Which Job Title in Year 2014 has lowest mean salary?

# %%
jobSal[jobSal["TotalPay"]==jobSal["TotalPay"].min()]
# Out:
#                  JobTitle  TotalPay  Year
# 836  Special Assistant 15       0.0  2014

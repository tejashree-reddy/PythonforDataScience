# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
movies=pd.read_csv("HollywoodMovies.csv")
movies
# Out:
#                                          Movie              LeadStudio  \
# 0                                 Spider-Man 3                    Sony
# 1                              Shrek the Third               Paramount
# 2                                 Transformers               Paramount
# 3     Pirates of the Caribbean: At World's End                  Disney
# 4    Harry Potter and the Order of the Phoenix             Warner Bros
# ..                                         ...                     ...
# 965                                The Canyons                     IFC
# 966                                   The Call                 TriStar
# 967                        The English Teacher  Cinedigm Entertainment
# 968                       John Dies at the End                Magnolia
# 969                                   Lovelace              Radius-TWC
#
#      RottenTomatoes  AudienceScore          Story      Genre  \
# 0              61.0           54.0  Metamorphosis     Action
# 1              42.0           57.0          Quest  Animation
# 2              57.0           89.0  Monster Force     Action
# 3              45.0           74.0         Rescue     Action
# 4              78.0           82.0          Quest  Adventure
# ..              ...            ...            ...        ...
# 965            22.0            NaN            NaN        NaN
# 966            43.0           66.0            NaN        NaN
# 967            42.0            NaN            NaN        NaN
# 968            61.0           53.0            NaN        NaN
# 969            55.0           37.0            NaN  Biography
#
#      TheatersOpenWeek  OpeningWeekend  BOAvgOpenWeekend  DomesticGross  \
# 0              4252.0          151.10           35540.0         336.53
# 1              4122.0          121.60           29507.0         322.72
# 2              4011.0           70.50           17577.0         319.25
# 3              4362.0          114.70           26302.0         309.42
# 4              4285.0           77.10           17998.0         292.00
# ..                ...             ...               ...            ...
# 965               1.0            0.01           13351.0           0.06
# 966            2507.0           17.12            6828.0          51.87
# 967               2.0            0.01            3001.0           0.10
# 968               1.0            0.01           12467.0           0.14
# 969             118.0            0.18            1564.0           0.36
#
#      ForeignGross  WorldGross  Budget  Profitability  OpenProfit  Year
# 0          554.34      890.87   258.0         345.30       58.57  2007
# 1          476.24      798.96   160.0         499.35       76.00  2007
# 2          390.46      709.71   150.0         473.14       47.00  2007
# 3          654.00      963.42   300.0         321.14       38.23  2007
# 4          647.88      939.89   150.0         626.59       51.40  2007
# ..            ...         ...     ...            ...         ...   ...
# 965          0.14        0.19     NaN          77.21         NaN  2013
# 966         16.70       68.57    13.0         527.48      131.69  2013
# 967          0.06        0.10     NaN            NaN         NaN  2013
# 968           NaN        0.14     1.0          14.20        1.00  2013
# 969          1.17        1.52    10.0          15.25        1.80  2013
#
# [970 rows x 16 columns]

# %%
movies.columns
# Out:
# Index(['Movie', 'LeadStudio', 'RottenTomatoes', 'AudienceScore', 'Story',
#        'Genre', 'TheatersOpenWeek', 'OpeningWeekend', 'BOAvgOpenWeekend',
#        'DomesticGross', 'ForeignGross', 'WorldGross', 'Budget',
#        'Profitability', 'OpenProfit', 'Year'],
#       dtype='object')

# %%
data=movies[["Movie","AudienceScore","Story"]]
data
# Out:
#                                          Movie  AudienceScore          Story
# 0                                 Spider-Man 3           54.0  Metamorphosis
# 1                              Shrek the Third           57.0          Quest
# 2                                 Transformers           89.0  Monster Force
# 3     Pirates of the Caribbean: At World's End           74.0         Rescue
# 4    Harry Potter and the Order of the Phoenix           82.0          Quest
# ..                                         ...            ...            ...
# 965                                The Canyons            NaN            NaN
# 966                                   The Call           66.0            NaN
# 967                        The English Teacher            NaN            NaN
# 968                       John Dies at the End           53.0            NaN
# 969                                   Lovelace           37.0            NaN
#
# [970 rows x 3 columns]

# %% [markdown]
# ##### 1.Find the highest rated movie in the“Quest” story type.

# %%
quest=data.loc[data["Story"]=="Quest"].reset_index()
quest
# Out:
#     index                                              Movie  AudienceScore  \
# 0       1                                    Shrek the Third           57.0
# 1       4          Harry Potter and the Order of the Phoenix           82.0
# 2       5                                        I Am Legend           69.0
# 3      28                                 Meet the Robinsons           75.0
# 4      49                                        The Kingdom           78.0
# 5      56                                             Hitman           61.0
# 6      58                                           Stardust           86.0
# 7      70                                        The Reaping           53.0
# 8      84                                    Lions for Lambs           48.0
# 9     114              The Mummy: Tomb of the Dragon Emperor           40.0
# 10    115                 Journey to the Center of the Earth           55.0
# 11    135                                        Fool's Gold           53.0
# 12    153                                        Speed Racer           61.0
# 13    185                                       The Bank Job           74.0
# 14    218                                Under the Same Moon           37.0
# 15    222                                      The Longshots           39.0
# 16    224                                           Doomsday           47.0
# 17    241             Harry Potter and the Half-Blood Prince           75.0
# 18    250                     Ice Age: Dawn of the Dinosaurs           72.0
# 19    252     Night at the Museum: Battle of the Smithsonian           60.0
# 20    286                             Race to Witch Mountain           50.0
# 21    304                                           Year One           31.0
# 22    321                                               Push           47.0
# 23    323                                        The Soloist           59.0
# 24    339                                          Astro Boy           53.0
# 25    341                                           Inkheart           51.0
# 26    343                                    The Hurt Locker           83.0
# 27    351                                             Amelia           35.0
# 28    365                               Dragonball Evolution           28.0
# 29    371                                           The Road           65.0
# 30    372                                   Taking Woodstock           48.0
# 31    389                                Clash of the Titans           48.0
# 32    413                                         Green Zone           60.0
# 33    417        Harry Potter and the Deathly Hallows Part 1           87.0
# 34    472                                    The Book of Eli           68.0
# 35    474  The Chronicles of Narnia: The Voyage of the Da...           63.0
# 36    483                                 The Last Airbender           42.0
# 37    532                                Conan the Barbarian           34.0
# 38    537                                       Dolphin Tale           81.0
# 39    553                                              Hanna           67.0
# 40    586         Pirates of the Caribbean:On Stranger Tides           61.0
# 41    588                                      Puss In Boots           76.0
# 42    593                                                Rio           73.0
# 43    595                                            Sanctum           39.0
# 44    604                Spy Kids: All The Time in the World           40.0
# 45    605                                       Sucker Punch           48.0
# 46    610                           The Adventures of Tintin           78.0
# 47    620                                          The Eagle           43.0
# 48    629                                        The Muppets           87.0
# 49    641                     Transformers: Dark of the Moon           67.0
# 50    649                                    Winnie The Pooh           79.0
#
#     Story
# 0   Quest
# 1   Quest
# 2   Quest
# 3   Quest
# 4   Quest
# 5   Quest
# 6   Quest
# 7   Quest
# 8   Quest
# 9   Quest
# 10  Quest
# 11  Quest
# 12  Quest
# 13  Quest
# 14  Quest
# 15  Quest
# 16  Quest
# 17  Quest
# 18  Quest
# 19  Quest
# 20  Quest
# 21  Quest
# 22  Quest
# 23  Quest
# 24  Quest
# 25  Quest
# 26  Quest
# 27  Quest
# 28  Quest
# 29  Quest
# 30  Quest
# 31  Quest
# 32  Quest
# 33  Quest
# 34  Quest
# 35  Quest
# 36  Quest
# 37  Quest
# 38  Quest
# 39  Quest
# 40  Quest
# 41  Quest
# 42  Quest
# 43  Quest
# 44  Quest
# 45  Quest
# 46  Quest
# 47  Quest
# 48  Quest
# 49  Quest
# 50  Quest

# %%
quest["AudienceScore"].max()
# Out:
# 87.0

# %%
quest.loc[quest["AudienceScore"]==87]
# Out:
#     index                                        Movie  AudienceScore  Story
# 33    417  Harry Potter and the Deathly Hallows Part 1           87.0  Quest
# 48    629                                  The Muppets           87.0  Quest

# %%
quest.max()
# Out:
# index                 649
# Movie            Year One
# AudienceScore          87
# Story               Quest
# dtype: object

# %%
quest[quest["AudienceScore"] == quest["AudienceScore"].max()]
# Out:
#     index                                        Movie  AudienceScore  Story
# 33    417  Harry Potter and the Deathly Hallows Part 1           87.0  Quest
# 48    629                                  The Muppets           87.0  Quest

# %% [markdown]
# ##### 2.Find the genre in which there has been the greatest number of movie releases

# %%
genre=movies.groupby("Genre").count().reset_index()
genre
# Out:
#           Genre  Movie  LeadStudio  RottenTomatoes  AudienceScore  Story  \
# 0        Action    166         162             165            165    156
# 1     Adventure     30          30              30             30     29
# 2     Animation     51          51              51             51     48
# 3     Biography     14          14              14             14     13
# 4        Comedy    177         175             172            172    169
# 5         Crime     15          15              15             15     15
# 6   Documentary      7           6               5              5      5
# 7         Drama    109         109              97             97     89
# 8       Fantasy      6           6               6              6      6
# 9        Horror     52          51              51             51     48
# 10      Musical      4           4               4              4      3
# 11      Mystery      5           5               5              5      5
# 12      Romance     20          20              19             19     19
# 13     Thriller     35          35              35             35     32
#
#     TheatersOpenWeek  OpeningWeekend  BOAvgOpenWeekend  DomesticGross  \
# 0                165             166               165            166
# 1                 30              30                30             30
# 2                 51              51                50             51
# 3                 14              14                14             14
# 4                172             177               170            177
# 5                 13              15                13             15
# 6                  7               7                 7              7
# 7                102             109               101            109
# 8                  5               6                 5              6
# 9                 50              51                50             52
# 10                 4               4                 4              4
# 11                 5               5                 5              5
# 12                19              20                19             20
# 13                34              35                34             35
#
#     ForeignGross  WorldGross  Budget  Profitability  OpenProfit  Year
# 0            164         165     164            164         164   166
# 1             30          30      30             30          30    30
# 2             51          51      51             51          51    51
# 3             14          14      14             14          14    14
# 4            169         172     169            168         168   177
# 5             15          15      15             15          15    15
# 6              4           5       5              5           5     7
# 7             93          97      96             96          96   109
# 8              6           6       6              6           6     6
# 9             51          52      51             51          50    52
# 10             4           4       4              4           4     4
# 11             5           5       5              5           5     5
# 12            20          20      20             20          20    20
# 13            35          35      35             35          35    35

# %%
maxMovieReleases=genre["Movie"].max()

# %%
genre.loc[genre["Movie"]==maxMovieReleases]
# print("Greatest number of movie releases are ",genre.loc[genre["Movie"]==maxMovieReleases] )
# Out:
#     Genre  Movie  LeadStudio  RottenTomatoes  AudienceScore  Story  \
# 4  Comedy    177         175             172            172    169
#
#    TheatersOpenWeek  OpeningWeekend  BOAvgOpenWeekend  DomesticGross  \
# 4               172             177               170            177
#
#    ForeignGross  WorldGross  Budget  Profitability  OpenProfit  Year
# 4           169         172     169            168         168   177

# %%
movies["Genre"].value_counts()
# Out:
# Comedy         177
# Action         166
# Drama          109
# Horror          52
# Animation       51
# Thriller        35
# Adventure       30
# Romance         20
# Crime           15
# Biography       14
# Documentary      7
# Fantasy          6
# Mystery          5
# Musical          4
# Name: Genre, dtype: int64

# %% [markdown]
# ##### 3.Print the names of the top five movies with the costliest budgets.

# %%
HighestBudget=movies.nlargest(5, ['Budget'])
HighestBudget[["Movie","Budget"]].reset_index()
# Out:
#    index                                       Movie  Budget
# 0      3    Pirates of the Caribbean: At World's End   300.0
# 1    468                                     Tangled   260.0
# 2      0                                Spider-Man 3   258.0
# 3    241      Harry Potter and the Half-Blood Prince   250.0
# 4    586  Pirates of the Caribbean:On Stranger Tides   250.0

# %% [markdown]
# ##### .Is there any correspondence between the critics’ evaluation of a movie and itsacceptance by the public?
# ##### Find out, by plotting the net profitability of a movie against the ratings it receives on Rotten Tomatoes.

# %%
plt.scatter(movies["RottenTomatoes"],movies["AudienceScore"])
plt.xlabel("RottenTomatoes")
plt.ylabel("AudienceScore")
# Out:
# Text(0, 0.5, 'AudienceScore')

# %%
movies['RottenTomatoes'].corr(movies['AudienceScore'])
# Out:
# 0.7029076919497171

# %%
movies.corr()
# Out:
#                   RottenTomatoes  AudienceScore  TheatersOpenWeek  \
# RottenTomatoes          1.000000       0.702908         -0.195955
# AudienceScore           0.702908       1.000000          0.026551
# TheatersOpenWeek       -0.195955       0.026551          1.000000
# OpeningWeekend          0.108582       0.298642          0.628137
# BOAvgOpenWeekend        0.230584       0.262906         -0.031266
# DomesticGross           0.230396       0.432542          0.589012
# ForeignGross            0.189916       0.341298          0.484370
# WorldGross              0.204155       0.383771          0.533982
# Budget                  0.070556       0.215915          0.606975
# Profitability           0.077520       0.084666          0.016380
# OpenProfit             -0.075175      -0.096767          0.052577
# Year                    0.129491       0.039294         -0.165133
#
#                   OpeningWeekend  BOAvgOpenWeekend  DomesticGross  \
# RottenTomatoes          0.108582          0.230584       0.230396
# AudienceScore           0.298642          0.262906       0.432542
# TheatersOpenWeek        0.628137         -0.031266       0.589012
# OpeningWeekend          1.000000          0.423558       0.903360
# BOAvgOpenWeekend        0.423558          1.000000       0.419979
# DomesticGross           0.903360          0.419979       1.000000
# ForeignGross            0.767212          0.369447       0.859419
# WorldGross              0.841989          0.410732       0.938719
# Budget                  0.686581          0.287100       0.696179
# Profitability           0.142681          0.099315       0.161482
# OpenProfit              0.108992          0.047072       0.043403
# Year                   -0.057527          0.029245      -0.050031
#
#                   ForeignGross  WorldGross    Budget  Profitability  \
# RottenTomatoes        0.189916    0.204155  0.070556       0.077520
# AudienceScore         0.341298    0.383771  0.215915       0.084666
# TheatersOpenWeek      0.484370    0.533982  0.606975       0.016380
# OpeningWeekend        0.767212    0.841989  0.686581       0.142681
# BOAvgOpenWeekend      0.369447    0.410732  0.287100       0.099315
# DomesticGross         0.859419    0.938719  0.696179       0.161482
# ForeignGross          1.000000    0.983284  0.726094       0.113996
# WorldGross            0.983284    1.000000  0.741902       0.139417
# Budget                0.726094    0.741902  1.000000      -0.130797
# Profitability         0.113996    0.139417 -0.130797       1.000000
# OpenProfit           -0.021384    0.004111 -0.149687       0.891743
# Year                  0.069720    0.023840  0.017292       0.042413
#
#                   OpenProfit      Year
# RottenTomatoes     -0.075175  0.129491
# AudienceScore      -0.096767  0.039294
# TheatersOpenWeek    0.052577 -0.165133
# OpeningWeekend      0.108992 -0.057527
# BOAvgOpenWeekend    0.047072  0.029245
# DomesticGross       0.043403 -0.050031
# ForeignGross       -0.021384  0.069720
# WorldGross          0.004111  0.023840
# Budget             -0.149687  0.017292
# Profitability       0.891743  0.042413
# OpenProfit          1.000000  0.028924
# Year                0.028924  1.000000

# %%
plt.scatter(movies["RottenTomatoes"],movies["Profitability"])
plt.ylim(0,2000)
plt.xlabel("RottenTomatoes")
plt.ylabel("Profitability")
# Out:
# Text(0, 0.5, 'Profitability')

# %%
movies["RottenTomatoes"].corr(movies["Profitability"])
# Out:
# 0.07751956972942778

# %% [markdown]
# ##### Perform Operations on Files5.1: From the raw data below create a data frame
#     ##### 'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
#         'last_name': ['Miller', 'Jacobson', ".", 'Milner', 'Cooze'],
#             'age': [42, 52, 36, 24, 73], 'preTestScore': [4, 24, 31, ".", "."],
#                     'postTestScore': ["25,000", "94,000", 57, 62, 70]

# %%
df=pd.DataFrame({'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
                'last_name': ['Miller', 'Jacobson', ".", 'Milner', 'Cooze'], 
                'age': [42, 52, 36, 24, 73],
                'preTestScore': [4, 24, 31, ".", "."],
                'postTestScore': ["25,000", "94,000", 57, 62, 70]})
df
# Out:
#   first_name last_name  age preTestScore postTestScore
# 0      Jason    Miller   42            4        25,000
# 1      Molly  Jacobson   52           24        94,000
# 2       Tina         .   36           31            57
# 3       Jake    Milner   24            .            62
# 4        Amy     Cooze   73            .            70

# %% [markdown]
# ##### 5.2: Save the dataframe into a csv file as example.csv

# %%
df.to_csv('example.csv')

# %% [markdown]
# ##### 5.3: Read the example.csv and print the data frame

# %%
stu=pd.read_csv("example.csv",index_col=0)
stu
# Out:
#   first_name last_name  age preTestScore postTestScore
# 0      Jason    Miller   42            4        25,000
# 1      Molly  Jacobson   52           24        94,000
# 2       Tina         .   36           31            57
# 3       Jake    Milner   24            .            62
# 4        Amy     Cooze   73            .            70

# %% [markdown]
# ##### 5.4: Read the example.csv without column heading

# %%
pd.read_csv('example.csv', header=None)
# Out:
#      0           1          2    3             4              5
# 0  NaN  first_name  last_name  age  preTestScore  postTestScore
# 1  0.0       Jason     Miller   42             4         25,000
# 2  1.0       Molly   Jacobson   52            24         94,000
# 3  2.0        Tina          .   36            31             57
# 4  3.0        Jake     Milner   24             .             62
# 5  4.0         Amy      Cooze   73             .             70

# %% [markdown]
# ##### Question 5: Read the example.csv andmake the index columns as 'First Name’ and 'Last Name

# %%
stu.set_index(['first_name','last_name'])
# Out:
#                       age preTestScore postTestScore
# first_name last_name
# Jason      Miller      42            4        25,000
# Molly      Jacobson    52           24        94,000
# Tina       .           36           31            57
# Jake       Milner      24            .            62
# Amy        Cooze       73            .            70

# %% [markdown]
# ##### 5.6:  Print  the  data  frame  in  a  Boolean  form  as  True  or  False.  True  for  Null/  NaN values and false for non-nullvalues

# %%
stu.isnull()
# Out:
#    first_name  last_name    age  preTestScore  postTestScore
# 0       False      False  False         False          False
# 1       False      False  False         False          False
# 2       False      False  False         False          False
# 3       False      False  False         False          False
# 4       False      False  False         False          False

# %% [markdown]
# ##### 5.7: Read the dataframe by skipping first 3 rows and print the data frame

# %%
stu.iloc[3:]
# Out:
#   first_name last_name  age preTestScore postTestScore
# 3       Jake    Milner   24            .            62
# 4        Amy     Cooze   73            .            70

# %% [markdown]
# ### 5.8: Load a csv file while interpreting "," in strings around numbers as thousands seperators.
#
#  ##### Check the raw data 'postTestScore' column has, as thousands separator.
#  ##### Comma should be ignored while reading the data. It is default behaviour,but you need to give argument to read_csv function which makes sure commas are ignored

# %%
pd.read_csv("example.csv", thousands=",")
# Out:
#    Unnamed: 0 first_name last_name  age preTestScore  postTestScore
# 0           0      Jason    Miller   42            4          25000
# 1           1      Molly  Jacobson   52           24          94000
# 2           2       Tina         .   36           31             57
# 3           3       Jake    Milner   24            .             62
# 4           4        Amy     Cooze   73            .             70

# %%
d=pd.read_csv("example.csv", index_col=4).filter(regex='\d{4}')
d
# Out:
# Empty DataFrame
# Columns: []
# Index: [4, 24, 31, ., .]

# %% [markdown]
# ##### 6.Perform Operations on Files
# ##### 6.1: From the raw data below create a Pandas Series
#     'Amit', 'Bob', 'Kate', 'A', 'b', np.nan, 'Car', 'dog', 'cat'
#     a) Print all elements in lower case
#     b) Print all the elements in upper case
#     c) Print the length of all the element

# %%
lst=['Amit', 'Bob', 'Kate', 'A', 'b', np.nan, 'Car', 'dog', 'cat']
ser=pd.Series(lst)
ser
# Out:
# 0    Amit
# 1     Bob
# 2    Kate
# 3       A
# 4       b
# 5     NaN
# 6     Car
# 7     dog
# 8     cat
# dtype: object

# %%
L=ser.str.lower()

# %%
U=ser.str.upper()

# %%
Len=ser.str.len()

# %%
df=pd.DataFrame(lst)
df["Lower"]=L
df["Upper"]=U
df["Length"]=Len
df
# Out:
#       0 Lower Upper  Length
# 0  Amit  amit  AMIT     4.0
# 1   Bob   bob   BOB     3.0
# 2  Kate  kate  KATE     4.0
# 3     A     a     A     1.0
# 4     b     b     B     1.0
# 5   NaN   NaN   NaN     NaN
# 6   Car   car   CAR     3.0
# 7   dog   dog   DOG     3.0
# 8   cat   cat   CAT     3.0

# %% [markdown]
# ##### .2: From the raw data below create a Pandas Series
#    ##### ' Atul', 'John ', ' jack ', 'Sam'
#       a) Print all elements after stripping spaces from the left and right
#     b) Print all the elements after removing spaces from the left only
#     c) Print all the elements after removing spaces from the right only

# %%
lst1=[' Atul', 'John ', ' jack ', 'Sam']
s1=pd.Series(lst1)
s1
# Out:
# 0      Atul
# 1     John
# 2     jack
# 3       Sam
# dtype: object

# %%
s1.str.lstrip()
# Out:
# 0     Atul
# 1    John
# 2    jack
# 3      Sam
# dtype: object

# %%
s1.str.rstrip()
# Out:
# 0     Atul
# 1     John
# 2     jack
# 3      Sam
# dtype: object

# %%
s1.str.strip()
# Out:
# 0    Atul
# 1    John
# 2    jack
# 3     Sam
# dtype: object

# %% [markdown]
# ##### 6.3: -Create a series from the raw data below
#     'India_is_big', 'Population_is_huge', np.nan, 'Has_diverse_culture'
#     a)split the individual strings wherever ‘_’ comes and create a list out of it.
#     b)Access the individual element of a list
#     c)Expand the elements so that all individual elements get splitted by ‘_’ and insted of list returns individual elements

# %%
lst2=['India_is_big', 'Population_is_huge', np.nan, 'Has_diverse_culture']
s2=pd.Series(lst2)

# %%
slt=s2.str.split("_")
slt
# Out:
# 0           [India, is, big]
# 1     [Population, is, huge]
# 2                        NaN
# 3    [Has, diverse, culture]
# dtype: object

# %%
slt[1][2]
# Out:
# 'huge'

# %%
s2.str.split("_",expand=True)
# Out:
#             0        1        2
# 0       India       is      big
# 1  Population       is     huge
# 2         NaN      NaN      NaN
# 3         Has  diverse  culture

# %% [markdown]
# ##### 6.4: Create a series and replace either X or dog with XX-XX
#     'A', 'B', 'C', 'AabX', 'BacX','', np.nan, 'CABA', 'dog', 'cat'

# %%
lst3=['A', 'B', 'C', 'AabX', 'BacX','', np.nan, 'CABA', 'dog', 'cat']
s3=pd.Series(lst3)
s3
# Out:
# 0       A
# 1       B
# 2       C
# 3    AabX
# 4    BacX
# 5
# 6     NaN
# 7    CABA
# 8     dog
# 9     cat
# dtype: object

# %%
s3.str.replace("X","XX-XX")
# Out:
# 0           A
# 1           B
# 2           C
# 3    AabXX-XX
# 4    BacXX-XX
# 5
# 6         NaN
# 7        CABA
# 8         dog
# 9         cat
# dtype: object

# %% [markdown]
# ##### 6.5: Create a series and remove dollar from the numeric values
#     '12', '-$10', '$10,000'

# %%
lst4=['12', '-$10', '$10,000']
s4=pd.Series(lst4)
s4
# Out:
# 0         12
# 1       -$10
# 2    $10,000
# dtype: object

# %%
s4.str.replace("$","")
# Out:
# 0        12
# 1       -10
# 2    10,000
# dtype: object

# %% [markdown]
# ##### 6.6:-Create a series and reverse all lower case words
#     'india 1998', 'big country', np.nan

# %%
lst5=['india 1998', 'big country', np.nan]
s5=pd.Series(lst5)
s5
# Out:
# 0     india 1998
# 1    big country
# 2            NaN
# dtype: object

# %%
pat=r'[a-z]+'
repl=lambda m: m.group(0)[::-1]
pd.Series(['india 1998', 'big country', np.nan]).str.replace(pat,repl)
# Out:
# 0     aidni 1998
# 1    gib yrtnuoc
# 2            NaN
# dtype: object

# %% [markdown]
# ##### 6.7: Create pandas series and print true if value is alphanumeric in series or false if value is not alpha numeric in series.
#     '1', '2', '1a', '2b', '2003c'

# %%
lst6=['1', '2', '1a', '2b', '2003c']
s6=pd.Series(lst6)
s6
# Out:
# 0        1
# 1        2
# 2       1a
# 3       2b
# 4    2003c
# dtype: object

# %%
s6.str.isalnum()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# dtype: bool

# %% [markdown]
# ##### 6.8: Create pandas series and print true if value is containing ‘A’
#     '1', '2', '1a', '2b', 'America', 'VietnAm','vietnam', '2003c'

# %%
lst7=['1', '2', '1a', '2b', 'America', 'VietnAm','vietnam', '2003c']
s7=pd.Series(lst7)
s7
# Out:
# 0          1
# 1          2
# 2         1a
# 3         2b
# 4    America
# 5    VietnAm
# 6    vietnam
# 7      2003c
# dtype: object

# %%
s7.str.contains(pat = 'A')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6    False
# 7    False
# dtype: bool

# %% [markdown]
# ##### 6.9: Create pandas series and print in three columns value 0 or 1 is a or b or c exists in values
#     'a', 'a|b', np.nan, 'a|c'

# %%
lst8=['a', 'a|b', np.nan, 'a|c']
s8=pd.Series(lst8)
s8
# Out:
# 0      a
# 1    a|b
# 2    NaN
# 3    a|c
# dtype: object

# %%
s8.str.get_dummies(sep='|')
# Out:
#    a  b  c
# 0  1  0  0
# 1  1  1  0
# 2  0  0  0
# 3  1  0  1

# %% [markdown]
# ##### 6.10: Create pandas dataframe having keys and ltable and rtable as below -
#     'key': ['One', 'Two'], 'ltable': [1, 2]
#             'key': ['One', 'Two'], 'rtable': [4, 5]
#     Merge both the tables based of key

# %%
df1=pd.DataFrame({'key': ['One', 'Two'], 'ltable': [1, 2]})
df1
# Out:
#    key  ltable
# 0  One       1
# 1  Two       2

# %%
df2=pd.DataFrame({'key': ['One', 'Two'], 'rtable': [4, 5]})
df2
# Out:
#    key  rtable
# 0  One       4
# 1  Two       5

# %%
df1.merge(df2)
# Out:
#    key  ltable  rtable
# 0  One       1       4
# 1  Two       2       5
